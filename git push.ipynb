# %%
import os
import json
from google.colab import drive

drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/MedQuAD

# %%
# !git init

# %%
# !git config --global user.email "sodus1102@gmail.com"
# !git config --global user.name "Hong So"
